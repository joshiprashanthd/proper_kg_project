# %%
import pandas as pd
from pathlib import Path

# %%
csv_paths = [file for file in Path("./train").glob("*.csv")]
csv_paths
# Out:
# [PosixPath('train/angst-silver_train.csv'),
#  PosixPath('train/mhqa-b-subset_train.csv'),
#  PosixPath('train/medmcqa_train.csv'),
#  PosixPath('train/mhqa-b-all-labels.csv')]

# %% [markdown]
# # ANGST DATASET CLEANING

# %%
idx = 0
csv_path = csv_paths[idx]
df = pd.read_csv(csv_path)
df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  i woke up very early, 2 am. i just came out of...
# 1           1  ive been trying my damndest to improve myself ...
# 2           2  he lives on the other side of the country and ...
# 3           3  i work in retail and lately ive had some shit ...
# 4           4  i had my first one in november 2020, another 2...
#
#    depression_label  anxiety_label multilabel_clf_label multiclass_clf_label  \
# 0                 1              0               [1, 0]           Depression
# 1                 1              0               [1, 0]           Depression
# 2                 1              0               [1, 0]           Depression
# 3                 0              1               [0, 1]              Anxiety
# 4                 0              1               [0, 1]              Anxiety
#
#        id
# 0  4JEVyZ
# 1  3jkFBr
# 2  4DZQ7p
# 3  FSr2Vx
# 4  42FfcW

# %%
df.drop(columns=['depression_label', 'anxiety_label', 'multilabel_clf_label', 'Unnamed: 0'], inplace=True)
df.head()
# Out:
#                                                 text multiclass_clf_label  \
# 0  i woke up very early, 2 am. i just came out of...           Depression
# 1  ive been trying my damndest to improve myself ...           Depression
# 2  he lives on the other side of the country and ...           Depression
# 3  i work in retail and lately ive had some shit ...              Anxiety
# 4  i had my first one in november 2020, another 2...              Anxiety
#
#        id
# 0  4JEVyZ
# 1  3jkFBr
# 2  4DZQ7p
# 3  FSr2Vx
# 4  42FfcW

# %%
df['multiclass_clf_label'].value_counts()
# Out:
# multiclass_clf_label
# Normal                             3349
# Depression                         2705
# Anxiety                            1048
# Comorbid (Depression + Anxiety)     565
# Name: count, dtype: int64

# %%
df.loc[:, 'option1'] = "Depression"
df.loc[:, 'option2'] = "Anxiety"
df.loc[:, 'option3'] = "Comorbid (Depression + Anxiety)"
df.loc[:, 'option4'] = "Normal"

# %%
df.rename(columns={'multiclass_clf_label': 'answer'}, inplace=True)
df.head()
# Out:
#                                                 text      answer      id  \
# 0  i woke up very early, 2 am. i just came out of...  Depression  4JEVyZ
# 1  ive been trying my damndest to improve myself ...  Depression  3jkFBr
# 2  he lives on the other side of the country and ...  Depression  4DZQ7p
# 3  i work in retail and lately ive had some shit ...     Anxiety  FSr2Vx
# 4  i had my first one in november 2020, another 2...     Anxiety  42FfcW
#
#       option1  option2                          option3 option4
# 0  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 1  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 2  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 3  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 4  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal

# %%
def correct_option_number_func(row):
    options = [row['option1'], row['option2'], row['option3'], row['option4']]
    return options.index(row['answer']) + 1

df['correct_option_number'] = df.apply(correct_option_number_func, axis=1)
df.head()
# Out:
#                                                 text      answer      id  \
# 0  i woke up very early, 2 am. i just came out of...  Depression  4JEVyZ
# 1  ive been trying my damndest to improve myself ...  Depression  3jkFBr
# 2  he lives on the other side of the country and ...  Depression  4DZQ7p
# 3  i work in retail and lately ive had some shit ...     Anxiety  FSr2Vx
# 4  i had my first one in november 2020, another 2...     Anxiety  42FfcW
#
#       option1  option2                          option3 option4  \
# 0  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 1  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 2  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 3  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 4  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
#
#    correct_option_number
# 0                      1
# 1                      1
# 2                      1
# 3                      2
# 4                      2

# %%
df['question'] = "Classify whether the given text is Depression, Anxiety or Comorbid (Depression + Anxiety) or Normal\n\n" + df['text']

# %%
df.head()
# Out:
#                                                 text      answer      id  \
# 0  i woke up very early, 2 am. i just came out of...  Depression  4JEVyZ
# 1  ive been trying my damndest to improve myself ...  Depression  3jkFBr
# 2  he lives on the other side of the country and ...  Depression  4DZQ7p
# 3  i work in retail and lately ive had some shit ...     Anxiety  FSr2Vx
# 4  i had my first one in november 2020, another 2...     Anxiety  42FfcW
#
#       option1  option2                          option3 option4  \
# 0  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 1  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 2  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 3  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
# 4  Depression  Anxiety  Comorbid (Depression + Anxiety)  Normal
#
#    correct_option_number                                           question
# 0                      1  Classify whether the given text is Depression,...
# 1                      1  Classify whether the given text is Depression,...
# 2                      1  Classify whether the given text is Depression,...
# 3                      2  Classify whether the given text is Depression,...
# 4                      2  Classify whether the given text is Depression,...

# %%
df = df[['id', 'question', 'option1', 'option2', 'option3', 'option4', 'answer', 'correct_option_number']]
df.head()
# Out:
#        id                                           question     option1  \
# 0  4JEVyZ  Classify whether the given text is Depression,...  Depression
# 1  3jkFBr  Classify whether the given text is Depression,...  Depression
# 2  4DZQ7p  Classify whether the given text is Depression,...  Depression
# 3  FSr2Vx  Classify whether the given text is Depression,...  Depression
# 4  42FfcW  Classify whether the given text is Depression,...  Depression
#
#    option2                          option3 option4      answer  \
# 0  Anxiety  Comorbid (Depression + Anxiety)  Normal  Depression
# 1  Anxiety  Comorbid (Depression + Anxiety)  Normal  Depression
# 2  Anxiety  Comorbid (Depression + Anxiety)  Normal  Depression
# 3  Anxiety  Comorbid (Depression + Anxiety)  Normal     Anxiety
# 4  Anxiety  Comorbid (Depression + Anxiety)  Normal     Anxiety
#
#    correct_option_number
# 0                      1
# 1                      1
# 2                      1
# 3                      2
# 4                      2

# %%
df.to_csv(csv_path.parent / f"{csv_path.stem}_cleaned.csv", index=False)

# %% [markdown]
# # MEDMCQA DATASET CLEANING

# %%
csv_path = csv_paths[2]
df = pd.read_csv(csv_path)
df.head()
# Out:
#                                      id  \
# 0  53f79833-21b0-4336-8ef4-404c687ec807
# 1  b72c9d20-5b2a-4353-ab60-fa1a899fde6b
# 2  8ae09b49-665e-45e3-ac3d-869ff1a96a44
# 3  4eafd9d8-b2ea-4f44-ac7f-a12103f61945
# 4  77e67056-21d4-4dad-ba62-f785e6ce4e38
#
#                                             question  \
# 0                                     Hypomimia is ?
# 1  Symptomatic treatment is not required in withd...
# 2  "Castration anxiety" is seen in which phase of...
# 3                              In Profound MR, IQ is
# 4  Postponing paying attention of conscious impul...
#
#                          opa                  opb  \
# 0  Decreased ability to copy  Decreased execution
# 1                   Cannabis             Morphine
# 2                       Oral                 Anal
# 3                      50-69                35-49
# 4                Sublimation          Suppression
#
#                                 opc                       opd  cop  \
# 0  Deficit of expression by gesture  Deficit of fluent speech    2
# 1                           Alcohol                   Cocaine    0
# 2                           Phallic                   Genital    2
# 3                             20-34                      < 20    3
# 4                             Humor              Anticipation    1
#
#   choice_type                                                exp subject_name  \
# 0      single  Ans. C. Deficit of expression by gestureHypomi...   Psychiatry
# 1      single  Since cannabis causes very mild withdrawal sym...   Psychiatry
# 2       multi  Phallic phase (3-5years): Male child develops ...   Psychiatry
# 3      single  IQ range for categoriesICD-10DSM-IVMild50-6950...   Psychiatry
# 4      single  Suppression is pushing of unwanted feelings in...   Psychiatry
#
#                                   topic_name
# 0                                        NaN
# 1  Substance Related and Addictive Disorders
# 2                                        NaN
# 3                           Child psychiatry
# 4                                        NaN

# %%
df.drop(columns=['choice_type'], inplace=True)
df.head()
# Out:
#                                      id  \
# 0  53f79833-21b0-4336-8ef4-404c687ec807
# 1  b72c9d20-5b2a-4353-ab60-fa1a899fde6b
# 2  8ae09b49-665e-45e3-ac3d-869ff1a96a44
# 3  4eafd9d8-b2ea-4f44-ac7f-a12103f61945
# 4  77e67056-21d4-4dad-ba62-f785e6ce4e38
#
#                                             question  \
# 0                                     Hypomimia is ?
# 1  Symptomatic treatment is not required in withd...
# 2  "Castration anxiety" is seen in which phase of...
# 3                              In Profound MR, IQ is
# 4  Postponing paying attention of conscious impul...
#
#                          opa                  opb  \
# 0  Decreased ability to copy  Decreased execution
# 1                   Cannabis             Morphine
# 2                       Oral                 Anal
# 3                      50-69                35-49
# 4                Sublimation          Suppression
#
#                                 opc                       opd  cop  \
# 0  Deficit of expression by gesture  Deficit of fluent speech    2
# 1                           Alcohol                   Cocaine    0
# 2                           Phallic                   Genital    2
# 3                             20-34                      < 20    3
# 4                             Humor              Anticipation    1
#
#                                                  exp subject_name  \
# 0  Ans. C. Deficit of expression by gestureHypomi...   Psychiatry
# 1  Since cannabis causes very mild withdrawal sym...   Psychiatry
# 2  Phallic phase (3-5years): Male child develops ...   Psychiatry
# 3  IQ range for categoriesICD-10DSM-IVMild50-6950...   Psychiatry
# 4  Suppression is pushing of unwanted feelings in...   Psychiatry
#
#                                   topic_name
# 0                                        NaN
# 1  Substance Related and Addictive Disorders
# 2                                        NaN
# 3                           Child psychiatry
# 4                                        NaN

# %%
df.rename(columns={"exp": "explanation", "opa": "option1", "opb": "option2", "opc": "option3", "opd": "option4", "cop": "correct_option_number", "subject_name": "subject", "topic_name": "topic"}, inplace=True)
df.head()
# Out:
#                                      id  \
# 0  53f79833-21b0-4336-8ef4-404c687ec807
# 1  b72c9d20-5b2a-4353-ab60-fa1a899fde6b
# 2  8ae09b49-665e-45e3-ac3d-869ff1a96a44
# 3  4eafd9d8-b2ea-4f44-ac7f-a12103f61945
# 4  77e67056-21d4-4dad-ba62-f785e6ce4e38
#
#                                             question  \
# 0                                     Hypomimia is ?
# 1  Symptomatic treatment is not required in withd...
# 2  "Castration anxiety" is seen in which phase of...
# 3                              In Profound MR, IQ is
# 4  Postponing paying attention of conscious impul...
#
#                      option1              option2  \
# 0  Decreased ability to copy  Decreased execution
# 1                   Cannabis             Morphine
# 2                       Oral                 Anal
# 3                      50-69                35-49
# 4                Sublimation          Suppression
#
#                             option3                   option4  \
# 0  Deficit of expression by gesture  Deficit of fluent speech
# 1                           Alcohol                   Cocaine
# 2                           Phallic                   Genital
# 3                             20-34                      < 20
# 4                             Humor              Anticipation
#
#    correct_option_number                                        explanation  \
# 0                      2  Ans. C. Deficit of expression by gestureHypomi...
# 1                      0  Since cannabis causes very mild withdrawal sym...
# 2                      2  Phallic phase (3-5years): Male child develops ...
# 3                      3  IQ range for categoriesICD-10DSM-IVMild50-6950...
# 4                      1  Suppression is pushing of unwanted feelings in...
#
#       subject                                      topic
# 0  Psychiatry                                        NaN
# 1  Psychiatry  Substance Related and Addictive Disorders
# 2  Psychiatry                                        NaN
# 3  Psychiatry                           Child psychiatry
# 4  Psychiatry                                        NaN

# %%
df['correct_option_number'] = df['correct_option_number'].apply(lambda x: x+1)
df.head()
# Out:
#                                      id  \
# 0  53f79833-21b0-4336-8ef4-404c687ec807
# 1  b72c9d20-5b2a-4353-ab60-fa1a899fde6b
# 2  8ae09b49-665e-45e3-ac3d-869ff1a96a44
# 3  4eafd9d8-b2ea-4f44-ac7f-a12103f61945
# 4  77e67056-21d4-4dad-ba62-f785e6ce4e38
#
#                                             question  \
# 0                                     Hypomimia is ?
# 1  Symptomatic treatment is not required in withd...
# 2  "Castration anxiety" is seen in which phase of...
# 3                              In Profound MR, IQ is
# 4  Postponing paying attention of conscious impul...
#
#                      option1              option2  \
# 0  Decreased ability to copy  Decreased execution
# 1                   Cannabis             Morphine
# 2                       Oral                 Anal
# 3                      50-69                35-49
# 4                Sublimation          Suppression
#
#                             option3                   option4  \
# 0  Deficit of expression by gesture  Deficit of fluent speech
# 1                           Alcohol                   Cocaine
# 2                           Phallic                   Genital
# 3                             20-34                      < 20
# 4                             Humor              Anticipation
#
#    correct_option_number                                        explanation  \
# 0                      3  Ans. C. Deficit of expression by gestureHypomi...
# 1                      1  Since cannabis causes very mild withdrawal sym...
# 2                      3  Phallic phase (3-5years): Male child develops ...
# 3                      4  IQ range for categoriesICD-10DSM-IVMild50-6950...
# 4                      2  Suppression is pushing of unwanted feelings in...
#
#       subject                                      topic
# 0  Psychiatry                                        NaN
# 1  Psychiatry  Substance Related and Addictive Disorders
# 2  Psychiatry                                        NaN
# 3  Psychiatry                           Child psychiatry
# 4  Psychiatry                                        NaN

# %%
df['answer'] = df.apply(lambda x: x['option' + str(x['correct_option_number'])], axis=1)
df.head()
# Out:
#                                      id  \
# 0  53f79833-21b0-4336-8ef4-404c687ec807
# 1  b72c9d20-5b2a-4353-ab60-fa1a899fde6b
# 2  8ae09b49-665e-45e3-ac3d-869ff1a96a44
# 3  4eafd9d8-b2ea-4f44-ac7f-a12103f61945
# 4  77e67056-21d4-4dad-ba62-f785e6ce4e38
#
#                                             question  \
# 0                                     Hypomimia is ?
# 1  Symptomatic treatment is not required in withd...
# 2  "Castration anxiety" is seen in which phase of...
# 3                              In Profound MR, IQ is
# 4  Postponing paying attention of conscious impul...
#
#                      option1              option2  \
# 0  Decreased ability to copy  Decreased execution
# 1                   Cannabis             Morphine
# 2                       Oral                 Anal
# 3                      50-69                35-49
# 4                Sublimation          Suppression
#
#                             option3                   option4  \
# 0  Deficit of expression by gesture  Deficit of fluent speech
# 1                           Alcohol                   Cocaine
# 2                           Phallic                   Genital
# 3                             20-34                      < 20
# 4                             Humor              Anticipation
#
#    correct_option_number                                        explanation  \
# 0                      3  Ans. C. Deficit of expression by gestureHypomi...
# 1                      1  Since cannabis causes very mild withdrawal sym...
# 2                      3  Phallic phase (3-5years): Male child develops ...
# 3                      4  IQ range for categoriesICD-10DSM-IVMild50-6950...
# 4                      2  Suppression is pushing of unwanted feelings in...
#
#       subject                                      topic  \
# 0  Psychiatry                                        NaN
# 1  Psychiatry  Substance Related and Addictive Disorders
# 2  Psychiatry                                        NaN
# 3  Psychiatry                           Child psychiatry
# 4  Psychiatry                                        NaN
#
#                              answer
# 0  Deficit of expression by gesture
# 1                          Cannabis
# 2                           Phallic
# 3                              < 20
# 4                       Suppression

# %%
df.to_csv(csv_path.parent / f"{csv_path.stem}_cleaned.csv", index=False)

# %% [markdown]
# # CLEAN MHQA DATASET

# %%
df = pd.read_csv("/home/sracha/proper_kg_project/base_llm_train_eval/dataset/train/mhqa-b-all-labels.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49734 entries, 0 to 49733
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     49734 non-null  int64
#  1   topic                  49734 non-null  object
#  2   type                   49734 non-null  object
#  3   question               49734 non-null  object
#  4   option1                49734 non-null  object
#  5   option2                49734 non-null  object
#  6   option3                49734 non-null  object
#  7   option4                49734 non-null  object
#  8   correct_option         0 non-null      float64
#  9   correct_option_number  49734 non-null  float64
#  10  correct_answer         49734 non-null  object
#  11  qid                    49734 non-null  int64
#  12  output_id              49734 non-null  int64
#  13  output_question        49734 non-null  object
#  14  output_decision        49734 non-null  object
#  15  output_explanation     49734 non-null  object
# dtypes: float64(2), int64(3), object(11)
# memory usage: 6.1+ MB

# %%
df.drop(columns=['correct_option', 'output_id', 'output_question', 'output_decision', 'output_explanation', "qid"], inplace=True, errors='ignore')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49734 entries, 0 to 49733
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     49734 non-null  int64
#  1   topic                  49734 non-null  object
#  2   type                   49734 non-null  object
#  3   question               49734 non-null  object
#  4   option1                49734 non-null  object
#  5   option2                49734 non-null  object
#  6   option3                49734 non-null  object
#  7   option4                49734 non-null  object
#  8   correct_option_number  49734 non-null  float64
#  9   correct_answer         49734 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.8+ MB

# %%
df.rename(columns={"correct_answer": "answer"}, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49734 entries, 0 to 49733
# Data columns (total 10 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     49734 non-null  int64
#  1   topic                  49734 non-null  object
#  2   type                   49734 non-null  object
#  3   question               49734 non-null  object
#  4   option1                49734 non-null  object
#  5   option2                49734 non-null  object
#  6   option3                49734 non-null  object
#  7   option4                49734 non-null  object
#  8   correct_option_number  49734 non-null  float64
#  9   answer                 49734 non-null  object
# dtypes: float64(1), int64(1), object(8)
# memory usage: 3.8+ MB

# %%
df.to_csv("./train/mhqa-b-all-labels_cleaned.csv", index=False)
