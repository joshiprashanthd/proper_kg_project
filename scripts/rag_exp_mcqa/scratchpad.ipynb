# %%
import re

# %%
text = """
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[can_be_qualified_by]->(Tail: 'Taxonomic', Definition: '1. Used for taxonomic or other systematic or hierarchical classification systems.')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_parent]->(Tail: 'Irrational thoughts', Definition: '<|NO_DEFINITION|>')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_parent]->(Tail: 'Impaired judgement', Definition: '1. Reduced ability to plan, poor decision making.')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_parent]->(Tail: 'Disturbance in judgement', Definition: '1. Maladaptive judgment resulting from wish-fulfilling, impulsive decisions based on need for immediate infantile gratification.')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_parent]->(Tail: 'Critical judgement', Definition: '<|NO_DEFINITION|>')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_parent]->(Tail: 'Automatic judgement', Definition: '<|NO_DEFINITION|>')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_parent]->(Tail: 'Prejudice', Definition: '1. A preconceived judgment made without factual basis.
2. attitude or opinion which predisposes an individual to make a preconceived judgment prior to objective evaluation; frequently an irrational attitude of hostility directed against an individual, group, or race or their supposed characteristics; do not confuse with BIAS.')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_child]->(Tail: 'MEMORY, INTELLIGENCE, JUDGEMENT, INSIGHT AND LEARNING', Definition: '<|NO_DEFINITION|>')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_child]->(Tail: 'Higher-level cognitive functions', Definition: '1. Specific mental functions especially dependent on the frontal lobes of the brain, including complex goal-directed behaviours such as decision-making, abstract thinking, planning and carrying out plans, mental flexibility, and deciding which behaviours are appropriate under what circumstances; often called executive functions.
2. Specific mental functions especially dependent on the frontal lobes of the brain, including complex goal-directed behaviours such as decision-making, abstract thinking, planning and carrying out plans, mental flexibility, and deciding which behaviours are appropriate under what circumstances; often called executive functions.')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_child]->(Tail: 'Higher-level cognitive functions', Definition: '1. Specific mental functions especially dependent on the frontal lobes of the brain, including complex goal-directed behaviours such as decision-making, abstract thinking, planning and carrying out plans, mental flexibility, and deciding which behaviours are appropriate under what circumstances; often called executive functions.
2. Specific mental functions especially dependent on the frontal lobes of the brain, including complex goal-directed behaviours such as decision-making, abstract thinking, planning and carrying out plans, mental flexibility, and deciding which behaviours are appropriate under what circumstances; often called executive functions.')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_parent]->(Tail: 'Loss of judgement', Definition: '<|NO_DEFINITION|>')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_parent]->(Tail: 'Lack of judgement', Definition: '<|NO_DEFINITION|>')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_child]->(Tail: 'Intellectual faculties', Definition: '<|NO_DEFINITION|>')
(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[has_child]->(Tail: 'Cognition', Definition: '1. Ability to think and use information.
2. The mental process of knowing, thinking, learning and judging; the psychological result of perception and learning and reasoning.
3. Intellectual or mental process whereby an organism obtains knowledge.
4. Use of memory, learning, thinking, problem-solving, abstraction, judgment, insight, intellectual capacity, calculation, and language
5. The operation of the mind by which an organism becomes aware of objects of thought or perception; it includes the mental activities associated with thinking, learning, and memory. [ISBN:0721619908]
6. Ability to execute complex mental processes
7. Act or process of knowing which includes awareness and judgment, perceiving, reasoning, and conceiving.
8. The content of cognitive or thinking processes.
9. the act or process of knowing, including awareness, judgement, perception, reasoning, and conceiving.')
"""

triplet = """(Head: 'Judgment', Definition: '1. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
2. Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion.
3. The act of assessing a situation or event.
4. The process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.
5. Mental act of comparing or evaluating choices within a given set of values frequently with the purpose of choosing a course of action.
6. process of discovering or asserting an objective or intrinsic relation between two objects or concepts; a faculty or power that enables a person to make judgments; the process of bringing to light and asserting the implicit meaning of a concept; a critical evaluation of a person or situation.')-[can_be_qualified_by]->(Tail: 'Taxonomic', Definition: '1. Used for taxonomic or other systematic or hierarchical classification systems.')"""

# %%
NO_DEF_PATTERN = re.compile(r'<\|\s*NO_DEFINITION\s*\|>', re.IGNORECASE)
FIRST_DEF_PATTERN = re.compile(
    r'(?sm)^\s*1\.\s*'           
    r'(.*?)'                     
    r'(?=(?:\r?\n)\s*\d+\.|\Z)' 
)
TRIPLET_PATTERN = re.compile(
    r"""(?sx)                     
    \(Head:\s*'(?P<head>.*?)',\s*Definition:\s*'(?P<head_def>.*?)'\)
    \s*-\[(?P<rel>.*?)\]->
    \s*\(Tail:\s*'(?P<tail>.*?)',\s*Definition:\s*'(?P<tail_def>.*?)'\)
    """
)

def extract_first_definition(def_text: str) -> str:
    if NO_DEF_PATTERN.search(def_text):
        return '<|NO_DEFINITION|>'
    m = FIRST_DEF_PATTERN.search(def_text)
    if m:
        text = m.group(1).strip()
    else:
        text = def_text.strip()
    return text.rstrip('.')

def keep_first_definition(triplets: list[str]) -> list[str]:
    cleaned = []
    for line in triplets:
        m = TRIPLET_PATTERN.search(line)
        if not m:
            continue

        head, head_def = m.group('head'), m.group('head_def')
        tail, tail_def = m.group('tail'), m.group('tail_def')
        rel = m.group('rel')

        h_def1 = extract_first_definition(head_def)
        t_def1 = extract_first_definition(tail_def)

        cleaned.append(
            f"(Head: '{head}', Definition: '{h_def1}')"
            f"-[{rel}]->"
            f"(Tail: '{tail}', Definition: '{t_def1}')"
        )
    return cleaned

# %%
keep_first_definition([triplet])
# Out:
# ["(Head: 'Judgment', Definition: 'Mental functions involved in discriminating between and evaluating different options, such as those involved in forming an opinion')-[can_be_qualified_by]->(Tail: 'Taxonomic', Definition: 'Used for taxonomic or other systematic or hierarchical classification systems')"]
