# %%
import pandas as pd

# %%
df = pd.read_json("./merged.jsonl", lines=True)

# %%
def convert_df_to_nested_structure(df):
    """
    Convert DataFrame to the desired nested JSON structure
    """
    result = []
    
    # Group by 'text' column
    grouped = df.groupby('text')
    
    for text, group in grouped:
        # Get the label (assuming it's the same for all rows with same text)
        label = group['label'].iloc[0]
        
        # Create symptom_phrases list
        symptom_phrases = []
        
        for _, row in group.iterrows():
            # Handle potentially stringified JSON columns
            def safe_parse_json(value):
                # Handle None/NaN values first
                if value is None:
                    return None
                
                # Check if it's a pandas NA/NaN (but not an array)
                if not isinstance(value, (list, dict)) and pd.isna(value):
                    return None
                
                # If it's already a list or dict, return as is
                if isinstance(value, (list, dict)):
                    return value
                
                # Handle empty string
                if isinstance(value, str) and value == '':
                    return None
                
                # Try to parse string as JSON
                if isinstance(value, str):
                    try:
                        return ast.literal_eval(value)
                    except:
                        try:
                            return json.loads(value)
                        except:
                            return value
                
                return value
            
            symptom_phrase = {
                "phrase": row['phrase'] if pd.notna(row['phrase']) else "",
                "symptom": row['symptom'] if pd.notna(row['symptom']) else "",
                "analysis": row['analysis'] if pd.notna(row['analysis']) else "",
                "symptom_phrase_label": safe_parse_json(row['symptom_phrase_label']),
                "faiss_rag_results": safe_parse_json(row['faiss_rag_results']),
                "bm25_rag_results": safe_parse_json(row['bm25_rag_results']),
                "usefulness_triplets_docs": safe_parse_json(row['usefulness_triplets_docs'])
            }
            
            symptom_phrases.append(symptom_phrase)
        
        # Create the final structure
        text_entry = {
            "text": text,
            "label": label,
            "symptom_phrases": symptom_phrases
        }
        
        result.append(text_entry)
    
    return result

# %%
def convert_df_to_flat_structure(df):
    """
    Alternative: Convert to structure where each row becomes a separate entry
    with single symptom_phrase instead of grouping
    """
    result = []
    
    for _, row in df.iterrows():
        def safe_parse_json(value):
            # Handle None/NaN values first
            if value is None:
                return None
            
            # Check if it's a pandas NA/NaN (but not an array)
            if not isinstance(value, (list, dict)) and pd.isna(value):
                return None
            
            # If it's already a list or dict, return as is
            if isinstance(value, (list, dict)):
                return value
            
            # Handle empty string
            if isinstance(value, str) and value == '':
                return None
            
            # Try to parse string as JSON
            if isinstance(value, str):
                try:
                    return ast.literal_eval(value)
                except:
                    try:
                        return json.loads(value)
                    except:
                        return value
            
            return value
        
        text_entry = {
            "text": row['text'] if pd.notna(row['text']) else "",
            "label": row['label'] if pd.notna(row['label']) else "",
            "symptom_phrases": {
                "phrase": row['phrase'] if pd.notna(row['phrase']) else "",
                "symptom": row['symptom'] if pd.notna(row['symptom']) else "",
                "analysis": row['analysis'] if pd.notna(row['analysis']) else "",
                "symptom_phrase_label": safe_parse_json(row['symptom_phrase_label']),
                "faiss_rag_results": safe_parse_json(row['faiss_rag_results']),
                "bm25_rag_results": safe_parse_json(row['bm25_rag_results']),
                "usefulness_triplets_docs": safe_parse_json(row['usefulness_triplets_docs'])
            }
        }
        
        result.append(text_entry)
    
    return result

# %%
def agg_func(x):
    return x.tolist()

df.groupby('text').agg(agg_func).reset_index().head()
# Out:
#                                                 text  \
# 0  18m 57 smoker 154 pounds i dont know if this s...
# 1  aphobes always talk about finding the right pe...
# 2  blazblue chronophantasma extend CUR2 deus ex m...
# 3  dear e, im sorry that you cant see me since il...
# 4  edit 2 i am done! i think i actually managed t...
#
#                                                label  \
# 0      [Anxiety, Anxiety, Anxiety, Anxiety, Anxiety]
# 1   [Normal, Normal, Normal, Normal, Normal, Normal]
# 2  [Normal, Normal, Normal, Normal, Normal, Norma...
# 3  [Normal, Normal, Normal, Normal, Normal, Norma...
# 4  [Normal, Normal, Normal, Normal, Normal, Norma...
#
#                                               phrase  \
# 0  [i deal with anxiety, i deal with anxiety, int...
# 1  [its sad that aphobes dont know these people e...
# 2  [I feel disconnected from reality., I spend ev...
# 3  [i want to spend my life waking up to you..., ...
# 4  [please wait outside store when done and ill e...
#
#                                              symptom  \
# 0  [Generalized anxiety, Generalized anxiety, Hea...
# 1  [Feeling marginalized, Desire for validation, ...
# 2  [Depersonalization, Chronic loneliness and anx...
# 3  [Longing for connection, Fear of loss, Fear of...
# 4  [Social anxiety, Shock or surprise, Financial ...
#
#                                             analysis  \
# 0  [The patient acknowledges experiencing anxiety...
# 1  [The patient feels a sense of sadness and frus...
# 2  [The patient expresses a feeling of detachment...
# 3  [The desire to share life with someone indicat...
# 4  [This phrase suggests an awareness of social d...
#
#                                       faiss_rag_docs  \
# 0  [[{'content': 'arise. Second, the worries asso...
# 1  [[{'content': 'failing to meet the cultural an...
# 2  [[{'content': 'the experience.
# Derealization i...
# 3  [[{'content': 'SE Axis
#
# Symptom Patterns in t...
# 4  [[{'content': 'of social situations because of...
#
#                                        bm25_rag_docs  \
# 0  [[{'content': 'disorder are more pervasive,
# pr...
# 1  [[{'content': 'are critical and dichotomous.
# ...
# 2  [[{'content': 'disorders and sexual dysfunctio...
# 3  [[{'content': 'Subjective Experience—SE Axis
# ...
# 4  [[{'content': 'individuals with social anxiety...
#
#                             usefulness_triplets_docs  \
# 0  [[{'triplet': '(Head: 'Generalized Anxiety Dis...
# 1  [[{'triplet': '(Head: 'Sex Discrimination', De...
# 2  [[{'triplet': '(Head: 'Depersonalization', Def...
# 3  [[{'triplet': '(Head: 'Someone to Have a Good ...
# 4  [[{'triplet': '(Head: 'Social Anxiety', Defini...
#
#                                 symptom_phrase_label
# 0  [{'phrase': 'i deal with anxiety', 'label': 'A...
# 1  [{'phrase': 'its sad that aphobes dont know th...
# 2  [{'phrase': 'I feel disconnected from reality....
# 3  [{'phrase': 'i want to spend my life waking up...
# 4  [{'phrase': 'please wait outside store when do...

# %%
df['symptom_phrase_label'].isna().sum()
# Out:
# np.int64(279)
