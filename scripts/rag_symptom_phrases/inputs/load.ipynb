# %%
import pandas as pd

# %%
df = pd.read_json("./merged.jsonl", lines=True)

# %%
for idx, row in df.iterrows():
    for sp in row['symptom_phrases']:
        print(sp['phrase'])
        print(sp['label'])
        print(sp['analysis'])
        print("\n")
# Out:
# an end to us?
# Depression
# The mention of an 'end' suggests feelings of loss and grief associated with a relationship, indicative of depressive symptoms related to separation or breakup. Hidden difficulties may include feelings of abandonment or unresolved emotional pain, potentially leading to prolonged sadness.
#
#
# squabbles fade and scars will heal.
# Anxiety
# The reference to fading squabbles and healing scars suggests a desire for resolution but also acknowledges past conflicts that may still cause anxiety. Hidden difficulties may include fear of repeating past mistakes or unresolved issues that could lead to future conflicts.
#
#
# mistakes on both sides, and down it fell.
# Depression
# This phrase reflects a sense of regret and acknowledgment of shared responsibility for the relationship's failure, which can contribute to feelings of guilt and sadness. Hidden difficulties could include self-blame or rumination over what went wrong, affecting self-esteem.
#
#
# ...
